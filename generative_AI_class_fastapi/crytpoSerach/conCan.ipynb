# %%
from ultralytics import YOLO

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="hxycT0x6sVeM2C0BGleO")
project = rf.workspace("eunbin").project("coinstore")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.1.42, to fix: `pip install ultralytics==8.0.196`
# Downloading Dataset Version Zip in CoinStore-1 to yolov8:: 100%|██████████| 69317/69317 [00:03<00:00, 17966.03it/s]
# Extracting Dataset Version Zip to CoinStore-1 in yolov8:: 100%|██████████| 3328/3328 [00:01<00:00, 2606.45it/s]

# %%
model = YOLO('yolov8n.pt')
results = model.train(data=r"D:\AIminiConPy\CoinStore-1\data.yaml", epochs=10)
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.1.0/yolov8n.pt to 'yolov8n.pt'...
# 100%|██████████| 6.23M/6.23M [00:01<00:00, 5.74MB/s]
# Ultralytics YOLOv8.1.42  Python-3.10.14 torch-2.2.2+cu121 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# engine\trainer: task=detect, mode=train, model=yolov8n.pt, data=D:\AIminiConPy\CoinStore-1\data.yaml, epochs=10, time=None, patience=100, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs\detect\train
# Overriding model.yaml nc=80 with nc=3
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    751897  ultralytics.nn.modules.head.Detect           [3, [64, 128, 256]]
# Model summary: 225 layers, 3011433 parameters, 3011417 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# AMP: checks passed
# train: Scanning D:\AIminiConPy\CoinStore-1\train\labels... 1449 images, 0 backgrounds, 0 corrupt: 100%|██████████| 1449/1449 [00:01<00:00, 756.87it/s]
# train: New cache created: D:\AIminiConPy\CoinStore-1\train\labels.cache
# val: Scanning D:\AIminiConPy\CoinStore-1\valid\labels... 140 images, 2 backgrounds, 0 corrupt: 100%|██████████| 140/140 [00:00<00:00, 444.76it/s]
# val: New cache created: D:\AIminiConPy\CoinStore-1\valid\labels.cache
# Plotting labels to runs\detect\train\labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001429, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to runs\detect\train
# Starting training for 10 epochs...
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/10      2.11G      1.161      2.596      1.556         13        640: 100%|██████████| 91/91 [00:15<00:00,  6.06it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:01<00:00,  3.88it/s]
#                    all        140        263      0.744      0.593      0.698      0.442
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/10      2.11G      1.084      1.744      1.446         12        640: 100%|██████████| 91/91 [00:12<00:00,  7.55it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:00<00:00,  5.70it/s]
#                    all        140        263      0.417      0.521      0.413      0.194
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/10      2.23G      1.083      1.541      1.444         19        640: 100%|██████████| 91/91 [00:11<00:00,  7.67it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:00<00:00,  5.79it/s]
#                    all        140        263      0.702      0.715       0.77      0.496
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/10      2.13G      1.061       1.31      1.438         23        640: 100%|██████████| 91/91 [00:11<00:00,  7.69it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:00<00:00,  6.06it/s]
#                    all        140        263      0.685      0.706      0.721      0.426
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/10      2.22G     0.9954      1.103      1.374         21        640: 100%|██████████| 91/91 [00:11<00:00,  7.71it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:00<00:00,  6.42it/s]
#                    all        140        263      0.806      0.792      0.821      0.538
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/10      2.23G     0.9567     0.9689      1.317         11        640: 100%|██████████| 91/91 [00:11<00:00,  7.71it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:00<00:00,  6.51it/s]
#                    all        140        263      0.837      0.757       0.83      0.554
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/10      2.23G     0.8977     0.8483      1.288         11        640: 100%|██████████| 91/91 [00:11<00:00,  7.70it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:00<00:00,  6.85it/s]
#                    all        140        263      0.865      0.862      0.914      0.629
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/10      2.23G     0.8803     0.7615      1.283         14        640: 100%|██████████| 91/91 [00:11<00:00,  7.71it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:00<00:00,  6.85it/s]
#                    all        140        263      0.865      0.898      0.914      0.629
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/10      2.22G     0.8076     0.6684       1.21         22        640: 100%|██████████| 91/91 [00:11<00:00,  7.70it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:00<00:00,  6.82it/s]
#                    all        140        263      0.866       0.89      0.929      0.653
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/10      2.23G     0.7808     0.6213      1.187         10        640: 100%|██████████| 91/91 [00:11<00:00,  7.68it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:00<00:00,  6.83it/s]
#                    all        140        263      0.889      0.876      0.926       0.67
# 10 epochs completed in 0.049 hours.
# Optimizer stripped from runs\detect\train\weights\last.pt, 6.2MB
# Optimizer stripped from runs\detect\train\weights\best.pt, 6.2MB
#
# Validating runs\detect\train\weights\best.pt...
# Ultralytics YOLOv8.1.42  Python-3.10.14 torch-2.2.2+cu121 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# Model summary (fused): 168 layers, 3006233 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:01<00:00,  3.66it/s]
#                    all        140        263       0.89      0.876      0.926      0.671
#               cocacola        140         75      0.865      0.867      0.925      0.716
#                  fanta        140         92      0.902      0.901      0.941      0.677
#                 sprite        140         96      0.902      0.859      0.912      0.619
# Speed: 0.3ms preprocess, 1.9ms inference, 0.0ms loss, 1.7ms postprocess per image
# Results saved to runs\detect\train

# %%
from PIL import Image
import matplotlib.pyplot as plt
from ultralytics import YOLO
# YOLO 모델 로드 및 이미지에 대한 객체 감지 수행
model = YOLO(r'D:\AIminiConPy\runs\detect\train\weights\best.pt')
result = model("TEST111.PNG")

# 감지된 객체가 포함된 이미지를 표시
# 이 부분은 사용하고 있는 YOLO 라이브러리의 API에 맞게 조정해야 할 수 있습니다.
# 예를 들어, result 객체에 이미지를 직접 조작하거나 그리는 메서드가 포함되어 있을 수 있습니다.
# 만약 result 객체가 이미지 데이터를 포함하고 있다면, 아래와 같이 처리할 수 있습니다:

# 감지된 객체를 표시한 이미지를 직접 불러오기
im = Image.open("TEST111.PNG")
# 또는 감지 결과를 다루는 다른 방식에 따라
# im = Image.fromarray(result.some_method_to_get_image_array())

# 이미지를 Matplotlib을 사용하여 출력
plt.imshow(im)
plt.axis('off')  # 축을 표시하지 않음
plt.show()
result
# Out:
# image 1/1 d:\AIminiConPy\TEST111.PNG: 576x640 1 cocacola, 1 fanta, 1 sprite, 213.6ms
# Speed: 7.0ms preprocess, 213.6ms inference, 469.2ms postprocess per image at shape (1, 3, 576, 640)
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'cocacola', 1: 'fanta', 2: 'sprite'}
#  obb: None
#  orig_img: array([[[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         ...,
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]]], dtype=uint8)
#  orig_shape: (513, 598)
#  path: 'd:\\AIminiConPy\\TEST111.PNG'
#  probs: None
#  save_dir: 'runs\\detect\\predict'
#  speed: {'preprocess': 7.029533386230469, 'inference': 213.56558799743652, 'postprocess': 469.22755241394043}]

# %%
from PIL import Image
import matplotlib.pyplot as plt
im_array = result[0].plot()
im = Image.fromarray(im_array[..., ::-1])
plt.imshow(im)
plt.show()

# %%
import cv2
from ultralytics import YOLO
import matplotlib.pyplot as plt
import os
import time

# Initialize YOLO model
model = YOLO(r'D:\AIminiConPy\runs\detect\train\weights\best.pt')

# OpenCV camera capture
cap = cv2.VideoCapture(0)  # 0 corresponds to the default camera

detected_image_path = None

while True:
    ret, frame = cap.read()  # Read a frame from the camera
    
    # Perform object detection with YOLO
    results = model(frame)
    
    # Check if any objects were detected in any of the results
    objects_detected = False
    for result in results:
        if len(result):
            objects_detected = True
            break
    
    if objects_detected:
        print("Objects detected. Stopping...")
        
        # Save the detected image
        save_path = "detected_image.jpg"
        results[0].save(save_path)  # Save the first detection result
        detected_image_path = save_path
        
        break
    
    # If the result is a list
    if isinstance(results, list):
        # If the result is a list, iterate over each detection result
        for result in results:
            # Save the detection result with bounding boxes
            save_path = "temp_detection.jpg"
            result.save(save_path)
            
            # Read the saved image using OpenCV
            im = cv2.imread(save_path)
            
            # Display the image with detected objects using matplotlib
            plt.imshow(cv2.cvtColor(im, cv2.COLOR_BGR2RGB))  # Convert BGR to RGB for display
            plt.axis('off')  # Do not show axis
            plt.show()
            
            # Remove the temporary image file
            os.remove(save_path)
            
    else:
        # If the result is not a list, it is a single detection result
        # Save the detection result with bounding boxes
        save_path = "temp_detection.jpg"
        results.save(save_path)
        
        # Read the saved image using OpenCV
        im = cv2.imread(save_path)
        
        # Display the image with detected objects using matplotlib
        plt.imshow(cv2.cvtColor(im, cv2.COLOR_BGR2RGB))  # Convert BGR to RGB for display
        plt.axis('off')  # Do not show axis
        plt.show()
        
        # Remove the temporary image file
        os.remove(save_path)
    
    # Pause for 2 seconds
    time.sleep(2)
    
    # Press 'q' to quit the loop and close the camera
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the camera and close all OpenCV windows
cap.release()
cv2.destroyAllWindows()

# Display the detected image
if detected_image_path:
    detected_im = cv2.imread(detected_image_path)
    plt.imshow(cv2.cvtColor(detected_im, cv2.COLOR_BGR2RGB))
    plt.axis('off')
    plt.title("Detected Image")
    plt.show()
# Out:
# 0: 480x640 2 sprites, 99.4ms
# Speed: 2.0ms preprocess, 99.4ms inference, 237.5ms postprocess per image at shape (1, 3, 480, 640)
# Objects detected. Stopping...

# %%
from binance.client import Client
import os

# You can get an API key and secret by registering on the Binance website
# It's recommended to use environment variables for security reasons
api_key = os.environ.get('BINANCE_API_KEY')
api_secret = os.environ.get('BINANCE_API_SECRET')

# Create the Binance client, providing the API key and secret
client = Client(api_key, api_secret)

# Function to get the latest price of a cryptocurrency
def get_latest_price(symbol):
    ticker = client.get_symbol_ticker(symbol=symbol)
    return float(ticker['price'])

# List of cryptocurrencies to fetch prices for
cryptos = ['BTCUSDT', 'ETHUSDT', 'SOLUSDT', 'XRPUSDT', 'DOGEUSDT']

# Dictionary to store the latest prices
crypto_prices = {}

# Fetch the latest prices for each cryptocurrency
for crypto in cryptos:
    crypto_prices[crypto[:-4]] = get_latest_price(crypto)

# Print the current prices of the cryptocurrencies
for crypto, price in crypto_prices.items():
    print(f"The current price of {crypto} is: ${price}")

# USD amount you want to spend on buying cryptocurrencies
usd_to_spend = 2  # You can change this value to any amount of USD you wish to spend

# Calculate how much of each cryptocurrency you can buy with the specified USD amount
crypto_to_buy = {}
for crypto, price in crypto_prices.items():
    crypto_to_buy[crypto] = usd_to_spend / price

# Format the results to 8 decimal places
crypto_to_buy_formatted = {crypto: "{:.8f}".format(amount) for crypto, amount in crypto_to_buy.items()}

# Print how much of each cryptocurrency you can buy with the specified amount of USD, formatted to 8 decimal places
for crypto, amount in crypto_to_buy_formatted.items():
    print(f"With {usd_to_spend}$ = {amount} {crypto}.")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from binance.client import Client
#       2 import os
#       4 # You can get an API key and secret by registering on the Binance website
#       5 # It's recommended to use environment variables for security reasons
#
# File c:\Users\GF76\.conda\envs\sesac_gpu_env310\lib\site-packages\binance\__init__.py:9
#       1 """An unofficial Python wrapper for the Binance exchange API v3
#       2
#       3 .. moduleauthor:: Sam McHardy
#       4
#       5 """
#       7 __version__ = "1.0.19"
# ----> 9 from binance.client import Client, AsyncClient  # noqa
#      10 from binance.depthcache import DepthCacheManager, OptionsDepthCacheManager, ThreadedDepthCacheManager  # noqa
#      11 from binance.streams import BinanceSocketManager, ThreadedWebsocketManager  # noqa
#
# File c:\Users\GF76\.conda\envs\sesac_gpu_env310\lib\site-packages\binance\client.py:11
#       9 import requests
#      10 import time
# ---> 11 from Crypto.PublicKey import RSA
#      12 from Crypto.Hash import SHA256
#      13 from Crypto.Signature import pkcs1_15
#
# ModuleNotFoundError: No module named 'Crypto'

# %%
import cv2
from ultralytics import YOLO
import matplotlib.pyplot as plt
import os
import time
from binance.client import Client
import os


# Initialize YOLO model
model = YOLO(r'D:\Python\generative_AI_class_fastapi\crytpoSerach\runs\detect\train\weights\best.pt')

# OpenCV camera capture
cap = cv2.VideoCapture(0)  # 0 corresponds to the default camera

detected_image_path = None
detected_classes = ""
while True:
    ret, frame = cap.read()  # Read a frame from the camera
    
    # Perform object detection with YOLO
    results = model(frame)
    
    # Check if any objects were detected in any of the results
    objects_detected = False
    for result in results:
        # Assuming each 'result' in 'results' contains detected objects' information
        if len(result.boxes):  # Check if there are any detections
            objects_detected = True
            
            # Map class IDs to class names
            detected_classes = [result.names[int(cls)] for cls in result.boxes.cls.tolist()]
            print("Detected objects:", detected_classes)
            
            break

    if objects_detected:
        print("Objects detected. Stopping...")
        
        # Save the detected image
        save_path = "detected_image.jpg"
        results[0].save(save_path)  # Save the first detection result
        detected_image_path = save_path
        
        break
    
    # If the result is a list
    if isinstance(results, list):
        # If the result is a list, iterate over each detection result
        for result in results:
            # Save the detection result with bounding boxes
            save_path = "temp_detection.jpg"
            result.save(save_path)
            
            # Read the saved image using OpenCV
            im = cv2.imread(save_path)
            
            # Display the image with detected objects using matplotlib
            plt.imshow(cv2.cvtColor(im, cv2.COLOR_BGR2RGB))  # Convert BGR to RGB for display
            plt.axis('off')  # Do not show axis
            plt.show()
            
            # Remove the temporary image file
            os.remove(save_path)
            
    else:
        # If the result is not a list, it is a single detection result
        # Save the detection result with bounding boxes
        save_path = "temp_detection.jpg"
        results.save(save_path)
        
        # Read the saved image using OpenCV
        im = cv2.imread(save_path)
        
        # Display the image with detected objects using matplotlib
        plt.imshow(cv2.cvtColor(im, cv2.COLOR_BGR2RGB))  # Convert BGR to RGB for display
        plt.axis('off')  # Do not show axis
        plt.show()
        
        # Remove the temporary image file
        os.remove(save_path)
    
    # Pause for 2 seconds
    time.sleep(2)
    
    # Press 'q' to quit the loop and close the camera
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the camera and close all OpenCV windows
cap.release()
cv2.destroyAllWindows()

# Display the detected image
if detected_image_path:
    detected_im = cv2.imread(detected_image_path)
    plt.imshow(cv2.cvtColor(detected_im, cv2.COLOR_BGR2RGB))
    plt.axis('off')
    plt.title("Detected Image")
    plt.show()

############################################################################
reusltNum = 0

if detected_classes == ['cocacola']:
    reusltNum = 2
elif  detected_classes == ['sprite']:
    reusltNum = 1.5
elif  detected_classes == ['fanta']:
    reusltNum = 1

print(detected_classes)
print(reusltNum)

# You can get an API key and secret by registering on the Binance website
# It's recommended to use environment variables for security reasons
api_key = os.environ.get('BINANCE_API_KEY')
api_secret = os.environ.get('BINANCE_API_SECRET')

# Create the Binance client, providing the API key and secret
client = Client(api_key, api_secret)

# Function to get the latest price of a cryptocurrency
def get_latest_price(symbol):
    ticker = client.get_symbol_ticker(symbol=symbol)
    return float(ticker['price'])

# List of cryptocurrencies to fetch prices for
cryptos = ['BTCUSDT', 'ETHUSDT', 'SOLUSDT', 'XRPUSDT', 'DOGEUSDT']

# Dictionary to store the latest prices
crypto_prices = {}

# Fetch the latest prices for each cryptocurrency
for crypto in cryptos:
    crypto_prices[crypto[:-4]] = get_latest_price(crypto)

# Print the current prices of the cryptocurrencies
for crypto, price in crypto_prices.items():
    print(f"The current price of {crypto} is: ${price}")

# USD amount you want to spend on buying cryptocurrencies
usd_to_spend = reusltNum  # You can change this value to any amount of USD you wish to spend

# Calculate how much of each cryptocurrency you can buy with the specified USD amount
crypto_to_buy = {}
for crypto, price in crypto_prices.items():
    crypto_to_buy[crypto] = usd_to_spend / price

# Format the results to 8 decimal places
crypto_to_buy_formatted = {crypto: "{:.8f}".format(amount) for crypto, amount in crypto_to_buy.items()}

# Print how much of each cryptocurrency you can buy with the specified amount of USD, formatted to 8 decimal places
for crypto, amount in crypto_to_buy_formatted.items():
    print(f"With {usd_to_spend}$ = {amount} {crypto}.")


# class Coin(Base):
#     __tablename__ = 'coins' # 테이블 이름
#     name = Column(Integer, primary_key=True)             
#     drinkCan = Column(String), #result = 'cocacola' -- string
#     dollarPrice = Column(String)
#     realtimeBTC = Column(String)
#     realtimeETH = Column(String)
#     realtimeSOL = Column(String)
#     realtimeXRP = Column(String)
#     realtimeDOGE = Column(String)
#     BTCforDollar = Column(String)
#     ETHforDollar = Column(String)
#     SOLforDollar = Column(String)
#     XRPforDollar = Column(String)
#     DOGEforDollar = Column(String)
    # name = 'dollarPrice', result = '2'       - Int
    # name = 'realtimeBTC', reuslt = '651843' - float
    # name = 'realtimeETH', reuslt = '35236'  -float
    # name = 'realtimeSOL', reuslt = '725'    -float
    # name = 'realtimeXRP', reuslt = '1.25'      -float
    # name = 'realtimeDOGE', reuslt = '0.05'  -float
    # name = 'BTCforDollar', result = '0.0000235'  -float
    # name = 'ETHforDollar', result = '0.0002635'  -float
    # name = 'SOLforDollar', result = '0.0326235'  -float
    # name = 'XRPforDollar', result = '1.2346235'  -float
    # name = 'DOGEforDollar', result = '9.2346345' -float
# Out:
# 0: 480x640 (no detections), 122.0ms
# Speed: 9.0ms preprocess, 122.0ms inference, 1500.3ms postprocess per image at shape (1, 3, 480, 640)
# 0: 480x640 (no detections), 65.0ms
# Speed: 2.0ms preprocess, 65.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# 0: 480x640 1 fanta, 67.0ms
# Speed: 2.0ms preprocess, 67.0ms inference, 38.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected objects: ['fanta']
# Objects detected. Stopping...
# ['fanta']
# 1
# The current price of BTC is: $69639.05
# The current price of ETH is: $3430.17
# The current price of SOL is: $177.14
# The current price of XRP is: $0.5932
# The current price of DOGE is: $0.20055
# With 1$ = 0.00001436 BTC.
# With 1$ = 0.00029153 ETH.
# With 1$ = 0.00564525 SOL.
# With 1$ = 1.68577208 XRP.
# With 1$ = 4.98628771 DOGE.

# %%
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: python-binance in c:\users\gf76\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (1.0.19)
# Requirement already satisfied: requests in c:\users\gf76\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from python-binance) (2.31.0)
# Requirement already satisfied: six in c:\users\gf76\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from python-binance) (1.16.0)
# Requirement already satisfied: dateparser in c:\users\gf76\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from python-binance) (1.2.0)
# Requirement already satisfied: aiohttp in c:\users\gf76\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from python-binance) (3.9.3)
# Requirement already satisfied: ujson in c:\users\gf76\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from python-binance) (5.9.0)
# Requirement already satisfied: websockets in c:\users\gf76\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from python-binance) (12.0)
# Requirement already satisfied: pycryptodome in c:\users\gf76\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from python-binance) (3.20.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\gf76\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from aiohttp->python-binance) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\gf76\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from aiohttp->python-binance) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\gf76\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from aiohttp->python-binance) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\gf76\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from aiohttp->python-binance) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\gf76\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from aiohttp->python-binance) (1.9.4)
# Requirement already satisfied: python-dateutil in c:\users\gf76\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from dateparser->python-binance) (2.9.0.post0)
# Requirement already satisfied: pytz in c:\users\gf76\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from dateparser->python-binance) (2024.1)
# Requirement already satisfied: regex!=2019.02.19,!=2021.8.27 in c:\users\gf76\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from dateparser->python-binance) (2023.12.25)
# Requirement already satisfied: tzlocal in c:\users\gf76\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from dateparser->python-binance) (5.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\gf76\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests->python-binance) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\gf76\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests->python-binance) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\gf76\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests->python-binance) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\gf76\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests->python-binance) (2024.2.2)
# Requirement already satisfied: tzdata in c:\users\gf76\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tzlocal->dateparser->python-binance) (2024.1)
